# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import pprint
# %matplotlib inline

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "./output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

name = []
lat = []
lng = []
temp = []
humid = []
clouds = []
wind = []
country = []

# Loop through cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    
    try:
        name.append(response['name'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        humid.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        country.append((response['sys']['country']))
        results = response['name']
        print(f"Retrieving Results for" + results)
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Missing field/result... skipping.
# ------------
# Retrieving Results forCape Town
# ------------
# Retrieving Results forPuerto Ayora
# ------------
# Retrieving Results forEast London
# ------------
# Retrieving Results forNaze
# ------------
# Retrieving Results forPraia da Vitória
# ------------
# Retrieving Results forDingle
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forVaini
# ------------
# Retrieving Results forPort Elizabeth
# ------------
# Retrieving Results forHermanus
# ------------
# Retrieving Results forVanimo
# ------------
# Retrieving Results forViedma
# ------------
# Retrieving Results forWaingapu
# ------------
# Retrieving Results forAlbany
# ------------
# Retrieving Results forPunta Cardon
# ------------
# Retrieving Results forKargasok
# ------------
# Retrieving Results forRikitea
# ------------
# Retrieving Results forTasiilaq
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forHobart
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forBredasdorp
# ------------
# Retrieving Results forPort Alfred
# ------------
# Retrieving Results forGrabovo
# ------------
# Retrieving Results forOzernovskiy
# ------------
# Retrieving Results forKamina
# ------------
# Retrieving Results forQuang Ngai
# ------------
# Retrieving Results forAbhā
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forKapaa
# ------------
# Retrieving Results forOlafsvik
# ------------
# Retrieving Results forTabas
# ------------
# Retrieving Results forPasaje
# ------------
# Retrieving Results forNorman Wells
# ------------
# Retrieving Results forKajaani
# ------------
# Retrieving Results forPevek
# ------------
# Retrieving Results forPiskivka
# ------------
# Retrieving Results forHofn
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forSan Cristobal
# ------------
# Retrieving Results forThompson
# ------------
# Retrieving Results forSaint-Philippe
# ------------
# Retrieving Results forRibeira Grande
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forChui
# ------------
# Retrieving Results forBusselton
# ------------
# Retrieving Results forTuktoyaktuk
# ------------
# Retrieving Results forGeorge Town
# ------------
# Retrieving Results forUshuaia
# ------------
# Retrieving Results forMataura
# ------------
# Retrieving Results forPort Blair
# ------------
# Retrieving Results forAtuona
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forBatagay
# ------------
# Retrieving Results forYellowknife
# ------------
# Retrieving Results forBluff
# ------------
# Retrieving Results forAmapá
# ------------
# Retrieving Results forSenneterre
# ------------
# Retrieving Results forSur
# ------------
# Retrieving Results forCamacha
# ------------
# Retrieving Results forPunta Arenas
# ------------
# Retrieving Results forFaya
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forUuemõisa
# ------------
# Retrieving Results forBandarbeyla
# ------------
# Retrieving Results forQaanaaq
# ------------
# Retrieving Results forMahébourg
# ------------
# Retrieving Results forCastro
# ------------
# Retrieving Results forBeira
# ------------
# Retrieving Results forMarrakesh
# ------------
# Retrieving Results forPovenets
# ------------
# Retrieving Results forBengkulu
# ------------
# Retrieving Results forFairmont
# ------------
# Retrieving Results forPervomayskoye
# ------------
# Retrieving Results forFortuna
# ------------
# Retrieving Results forAvarua
# ------------
# Retrieving Results forTalaya
# ------------
# Retrieving Results forDikson
# ------------
# Retrieving Results forSão Filipe
# ------------
# Retrieving Results forGanzhou
# ------------
# Retrieving Results forYerbogachën
# ------------
# Retrieving Results forAmbilobe
# ------------
# Retrieving Results forBubaque
# ------------
# Retrieving Results forKavieng
# ------------
# Retrieving Results forButaritari
# ------------
# Retrieving Results forSitka
# ------------
# Retrieving Results forKamenka
# ------------
# Retrieving Results forPort-Gentil
# ------------
# Retrieving Results forSaldanha
# ------------
# Retrieving Results forEsperance
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forVao
# ------------
# Retrieving Results forKlaksvík
# ------------
# Retrieving Results forSan Clemente
# ------------
# Retrieving Results forChokurdakh
# ------------
# Retrieving Results forBathsheba
# ------------
# Retrieving Results forLūnāvāda
# ------------
# Retrieving Results forMoerai
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forCabo San Lucas
# ------------
# Retrieving Results forNew Norfolk
# ------------
# Retrieving Results forHong Kong
# ------------
# Retrieving Results forMollendo
# ------------
# Retrieving Results forLongyearbyen
# ------------
# Retrieving Results forAcapulco de Juárez
# ------------
# Retrieving Results forMiyoshi City
# ------------
# Retrieving Results forConstitución
# ------------
# Retrieving Results forBoralday
# ------------
# Retrieving Results forPorto-Novo
# ------------
# Retrieving Results forAmstelveen
# ------------
# Retrieving Results forSanta Isabel Rio Negro
# ------------
# Retrieving Results forAncud
# ------------
# Retrieving Results forSaskylakh
# ------------
# Retrieving Results forHelong
# ------------
# Retrieving Results forIlulissat
# ------------
# Retrieving Results forMatara
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forShache
# ------------
# Retrieving Results forGenhe
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forAlamosa
# ------------
# Retrieving Results forGinda
# ------------
# Retrieving Results forBilibino
# ------------
# Retrieving Results forSrednekolymsk
# ------------
# Retrieving Results forPangnirtung
# ------------
# Retrieving Results forKaitangata
# ------------
# Retrieving Results forMareeba
# ------------
# Retrieving Results forKrasnosel'kup
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forPonta do Sol
# ------------
# Retrieving Results forTiksi
# ------------
# Retrieving Results forPelotas
# ------------
# Retrieving Results forNioro
# ------------
# Retrieving Results forNanortalik
# ------------
# Retrieving Results forUmluj
# ------------
# Retrieving Results forEilat
# ------------
# Retrieving Results forPangoa
# ------------
# Retrieving Results forAngoche
# ------------
# Retrieving Results forLorengau
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forJamestown
# ------------
# Retrieving Results forSaint Paul Harbor
# ------------
# Retrieving Results forSan Nicolas
# ------------
# Retrieving Results forMandurah
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forSoyo
# ------------
# Retrieving Results forBar Harbor
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forAlekseyevsk
# ------------
# Retrieving Results forKondoa
# ------------
# Retrieving Results forVila Velha
# ------------
# Retrieving Results forMarzuq
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forLebu
# ------------
# Retrieving Results forBatouri
# ------------
# Retrieving Results forPuerto Madryn
# ------------
# Retrieving Results forYumen
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forSiquijor
# ------------
# Retrieving Results forBasco
# ------------
# Retrieving Results forGeneral Roca
# ------------
# Retrieving Results forHilo
# ------------
# Retrieving Results forSaint-Pierre
# ------------
# Retrieving Results forNikolskoye
# ------------
# Retrieving Results forMonterey
# ------------
# Retrieving Results forOktyabr'skoye
# ------------
# Retrieving Results forPort Lincoln
# ------------
# Retrieving Results forAkdepe
# ------------
# Retrieving Results forHalifax
# ------------
# Retrieving Results forFaanui
# ------------
# Retrieving Results forLima
# ------------
# Retrieving Results forPadang
# ------------
# Retrieving Results forSouillac
# ------------
# Retrieving Results forIqaluit
# ------------
# Retrieving Results forPokhara
# ------------
# Retrieving Results forClonakilty
# ------------
# Retrieving Results forRichards Bay
# ------------
# Retrieving Results forJumla
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forBarrow
# ------------
# Retrieving Results forShelburne
# ------------
# Retrieving Results forUpernavik
# ------------
# Retrieving Results forPuerto Escondido
# ------------
# Retrieving Results forBethel
# ------------
# Retrieving Results forHeinola
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forPresidente Epitácio
# ------------
# Retrieving Results forAksu
# ------------
# Retrieving Results forSangmélima
# ------------
# Retrieving Results forKambove
# ------------
# Retrieving Results forSantiago del Estero
# ------------
# Retrieving Results forUglekamensk
# ------------
# Retrieving Results forSão Miguel
# ------------
# Retrieving Results forCollege
# ------------
# Retrieving Results forMakushino
# ------------
# Retrieving Results forSevero-Kuril'sk
# ------------
# Retrieving Results forHudson Bay
# ------------
# Retrieving Results forMount Isa
# ------------
# Retrieving Results forTouros
# ------------
# Retrieving Results forKhatanga
# ------------
# Retrieving Results forCayenne
# ------------
# Retrieving Results forHomer
# ------------
# Retrieving Results forLompoc
# ------------
# Retrieving Results forAdré
# ------------
# Retrieving Results forTezu
# ------------
# Retrieving Results forKhovd
# ------------
# Retrieving Results forConceição do Rio Verde
# ------------
# Retrieving Results forMackay
# ------------
# Retrieving Results forBerlevåg
# ------------
# Retrieving Results forFairbanks
# ------------
# Retrieving Results forTaldan
# ------------
# Retrieving Results forBatticaloa
# ------------
# Retrieving Results forRjukan
# ------------
# Retrieving Results forKarratha
# ------------
# Retrieving Results forHithadhoo
# ------------
# Retrieving Results forSovetskiy
# ------------
# Retrieving Results forMalchevskaya
# ------------
# Retrieving Results forNdola
# ------------
# Retrieving Results forGrindavik
# ------------
# Retrieving Results forHrebinka
# ------------
# Retrieving Results forÖstersund
# ------------
# Retrieving Results forWasilla
# ------------
# Retrieving Results forLīsakovsk
# ------------
# Retrieving Results forClyde River
# ------------
# Retrieving Results forMar del Plata
# ------------
# Retrieving Results forQuatre Cocos
# ------------
# Retrieving Results forTernate
# ------------
# Retrieving Results forZonguldak
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forChernyshevskiy
# ------------
# Retrieving Results forYulara
# ------------
# Retrieving Results forAtar
# ------------
# Retrieving Results forZeya
# ------------
# Retrieving Results forSan Jose
# ------------
# Retrieving Results forManiitsoq
# ------------
# Retrieving Results forPhimai
# ------------
# Retrieving Results forItaituba
# ------------
# Retrieving Results forMuroto-misakicho
# ------------
# Retrieving Results forBambous Virieux
# ------------
# Retrieving Results forSevero-Yeniseyskiy
# ------------
# Retrieving Results forMawlaik
# ------------
# Retrieving Results forYar-Sale
# ------------
# Retrieving Results forOrlik
# ------------
# Retrieving Results forMeulaboh
# ------------
# Retrieving Results forHasaki
# ------------
# Retrieving Results forGardabani
# ------------
# Retrieving Results forNaruja
# ------------
# Retrieving Results forGrand Gaube
# ------------
# Retrieving Results forSanta Rosa
# ------------
# Retrieving Results forTe Anau
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forAsău
# ------------
# Retrieving Results forLloydminster
# ------------
# Retrieving Results forAgadez
# ------------
# Retrieving Results forBulgan
# ------------
# Retrieving Results forArraial do Cabo
# ------------
# Retrieving Results forNgunguru
# ------------
# Retrieving Results forKiryat Gat
# ------------
# Retrieving Results forIsangel
# ------------
# Retrieving Results forWeinan
# ------------
# Retrieving Results forAirai
# ------------
# Retrieving Results forBantacan
# ------------
# Retrieving Results forMbini
# ------------
# Retrieving Results forKipushi
# ------------
# Retrieving Results forGraaff-Reinet
# ------------
# Retrieving Results forKerchevskiy
# ------------
# Retrieving Results forSeveromuysk
# ------------
# Retrieving Results forKatsuura
# ------------
# Retrieving Results forColón
# ------------
# Retrieving Results forGuiratinga
# ------------
# Retrieving Results forDehlorān
# ------------
# Retrieving Results forLagoa
# ------------
# Retrieving Results forYaroslavskiy
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forWaipawa
# ------------
# Retrieving Results forAcaraú
# ------------
# Retrieving Results forMataruska Banja
# ------------
# Retrieving Results forDinguiraye
# ------------
# Retrieving Results forKahului
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forAfikpo
# ------------
# Retrieving Results forKalutara
# ------------
# Retrieving Results forSarakhs
# ------------
# Retrieving Results forGushikawa
# ------------
# Retrieving Results forPisco
# ------------
# Retrieving Results forVirginia Beach
# ------------
# Retrieving Results forInírida
# ------------
# Retrieving Results forMuzaffarabad
# ------------
# Retrieving Results forMuscat
# ------------
# Retrieving Results forHaines Junction
# ------------
# Retrieving Results forCodrington
# ------------
# Retrieving Results forVrangel'
# ------------
# Retrieving Results forSão José da Coroa Grande
# ------------
# Retrieving Results forMarsabit
# ------------
# Retrieving Results forVităneşti
# ------------
# Retrieving Results forRivière-du-Loup
# ------------
# Retrieving Results forWalsrode
# ------------
# Retrieving Results forParacatu
# ------------
# Retrieving Results forNur-Sultan
# ------------
# Retrieving Results forUthal
# ------------
# Retrieving Results forKorenovsk
# ------------
# Retrieving Results forYatou
# ------------
# Retrieving Results forKemin
# ------------
# Retrieving Results forNecochea
# ------------
# Retrieving Results forPorbandar
# ------------
# Retrieving Results forFos-sur-Mer
# ------------
# Retrieving Results forAginskoye
# ------------
# Retrieving Results forCoos Bay
# ------------
# Retrieving Results forKyabé
# ------------
# Retrieving Results forNovoagansk
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forBereket
# ------------
# Retrieving Results forBacabal
# ------------
# Retrieving Results forTahoua
# ------------
# Retrieving Results forAraguaçu
# ------------
# Retrieving Results forBelyy Yar
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forBull Savanna
# ------------
# Retrieving Results forNome
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forNarsaq
# ------------
# Retrieving Results forGuerrero Negro
# ------------
# Retrieving Results forUst'-Koksa
# ------------
# Retrieving Results forWanning
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forChristchurch
# ------------
# Retrieving Results forHuéscar
# ------------
# Retrieving Results forCarballo
# ------------
# Retrieving Results forNavahrudak
# ------------
# Retrieving Results forSudak
# ------------
# Retrieving Results forChaiyaphum
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forSalalah
# ------------
# Retrieving Results forXishan
# ------------
# Retrieving Results forSão João da Barra
# ------------
# Retrieving Results forNamatanai
# ------------
# Retrieving Results forDhāmnod
# ------------
# Retrieving Results forChallans
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forKerteminde
# ------------
# Retrieving Results forUst-Nera
# ------------
# Retrieving Results forLuena
# ------------
# Retrieving Results forOssora
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forArman'
# ------------
# Retrieving Results forFort-Shevchenko
# ------------
# Retrieving Results forUdachny
# ------------
# Retrieving Results forDeputatsky
# ------------
# Retrieving Results forAlofi
# ------------
# Retrieving Results forSan Patricio
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forPechenga
# ------------
# Retrieving Results forJand
# ------------
# Retrieving Results forLapua
# ------------
# Retrieving Results forMargate
# ------------
# Retrieving Results forPort Hedland
# ------------
# Retrieving Results forSanta Cruz de la Sierra
# ------------
# Retrieving Results forBoffa
# ------------
# Retrieving Results forMonrovia
# ------------
# Retrieving Results forJoshīmath
# ------------
# Retrieving Results forKaeo
# ------------
# Retrieving Results forTolga
# ------------
# Retrieving Results forLinjiang
# ------------
# Retrieving Results forCarnarvon
# ------------
# Retrieving Results forMarabu
# ------------
# Retrieving Results forMabaruma
# ------------
# Retrieving Results forPaamiut
# ------------
# Retrieving Results forVila Franca do Campo
# ------------
# Retrieving Results forCarbondale
# ------------
# Retrieving Results forPetropavlovsk-Kamchatskiy
# ------------
# Retrieving Results forVostok
# ------------
# Retrieving Results forLinxia Chengguanzhen
# ------------
# Retrieving Results forHavelock
# ------------
# Retrieving Results forCaramay
# ------------
# Retrieving Results forHaikou
# ------------
# Retrieving Results forHvide Sande
# ------------
# Retrieving Results forTokmak
# ------------
# Retrieving Results forMayumba
# ------------
# Retrieving Results forBoa Vista
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forMakakilo City
# ------------
# Retrieving Results forTongren
# ------------
# Retrieving Results forGeraldton
# ------------
# Retrieving Results forBoké
# ------------
# Retrieving Results forHambantota
# ------------
# Retrieving Results forSaint-Ambroise
# ------------
# Retrieving Results forSaint-Leu
# ------------
# Retrieving Results forLata
# ------------
# Retrieving Results forNichinan
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forLumsden
# ------------
# Retrieving Results forLaguna de Perlas
# ------------
# Retrieving Results forMaceió
# ------------
# Retrieving Results forLos Llanos de Aridane
# ------------
# Retrieving Results forCaravelas
# ------------
# Retrieving Results forSaint George
# ------------
# Retrieving Results forMsanga
# ------------
# Retrieving Results forCastricum
# ------------
# Retrieving Results forSibolga
# ------------
# Retrieving Results forBud
# ------------
# Retrieving Results forLaguna
# ------------
# Retrieving Results forPathein
# ------------
# Retrieving Results forThe Valley
# ------------
# Retrieving Results forInhambane
# ------------
# Retrieving Results forFlinders
# ------------
# Retrieving Results forBonthe
# ------------
# Retrieving Results forJaltenango
# ------------
# Retrieving Results forBhan
# ------------
# Retrieving Results forMehamn
# ------------
# Retrieving Results forPenzance
# ------------
# Retrieving Results forPort-Cartier
# ------------
# Retrieving Results forMuli
# ------------
# Retrieving Results forNouadhibou
# ------------
# Retrieving Results forCaçador
# ------------
# Retrieving Results forSisimiut
# ------------
# Retrieving Results forCorralillo
# ------------
# Retrieving Results forCaluquembe
# ------------
# Retrieving Results forConceição do Araguaia
# ------------
# Retrieving Results forKloulklubed
# ------------
# Retrieving Results forSkjervøy
# ------------
# Retrieving Results forBhakkar
# ------------
# Retrieving Results forGijang
# ------------
# Retrieving Results forLavrentiya
# ------------
# Retrieving Results forOstrovnoy
# ------------
# Retrieving Results forTamandaré
# ------------
# Retrieving Results forRaudeberg
# ------------
# Retrieving Results forShingū
# ------------
# Retrieving Results forKichera
# ------------
# Retrieving Results forSørland
# ------------
# Retrieving Results forArlit
# ------------
# Retrieving Results forBatemans Bay
# ------------
# Retrieving Results forBanda Aceh
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forCherskiy
# ------------
# Retrieving Results forOmsukchan
# ------------
# Retrieving Results forHamilton
# ------------
# Retrieving Results forEgvekinot
# ------------
# Retrieving Results forNoumea
# ------------
# Retrieving Results forVerāval
# ------------
# Retrieving Results forMagadan
# ------------
# Retrieving Results forPitimbu
# ------------
# Retrieving Results forCharters Towers
# ------------
# Retrieving Results forTalnakh
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forMartapura
# ------------
# Retrieving Results forAksha
# ------------
# Retrieving Results forGalveston
# ------------
# Retrieving Results forDhrol
# ------------
# Retrieving Results forMafinga
# ------------
# Retrieving Results forComodoro Rivadavia
# ------------
# Retrieving Results forLüderitz
# ------------
# Retrieving Results forTaltal
# ------------
# Retrieving Results forZhezkazgan
# ------------
# Retrieving Results forHigh Prairie
# ------------
# Retrieving Results forSuda
# ------------
# Retrieving Results forSkegness
# ------------
# Retrieving Results forTiarei
# ------------
# Retrieving Results forMajene
# ------------
# Retrieving Results forMergen
# ------------
# Retrieving Results forSheboygan
# ------------
# Retrieving Results forTsuruoka
# ------------
# Retrieving Results forUst'-Shonosha
# ------------
# Retrieving Results forWatertown
# ------------
# Retrieving Results forTorbay
# ------------
# Retrieving Results forYasothon
# ------------
# Retrieving Results forAntofagasta
# ------------
# Retrieving Results forSangar
# ------------
# Retrieving Results forOlinda
# ------------
# Retrieving Results forAmga
# ------------
# Retrieving Results forHay River
# ------------
# Retrieving Results forNkhotakota
# ------------
# Retrieving Results forMariehamn
# ------------
# Retrieving Results forCidreira
# ------------
# Retrieving Results forAuka
# ------------
# Retrieving Results forRawson
# ------------
# Retrieving Results forLuján
# ------------
# Retrieving Results forPlayas
# ------------
# Retrieving Results forKiama
# ------------
# Retrieving Results forBallina
# ------------
# Retrieving Results forManacapuru
# ------------
# Retrieving Results forLeningradskiy
# ------------
# Retrieving Results forKruisfontein
# ------------
# Retrieving Results forConde
# ------------
# Retrieving Results forChangping
# ------------
# Retrieving Results forSan Bernardo
# ------------
# Retrieving Results forTbilisskaya
# ------------
# Retrieving Results forDonji Milanovac
# ------------
# Retrieving Results forBang Saphan
# ------------
# Retrieving Results forSanta Rosalía
# ------------
# Retrieving Results forDagana
# ------------
# Retrieving Results forLa Roche-sur-Yon
# ------------
# Retrieving Results forSechura
# ------------
# Retrieving Results forAvera
# ------------
# Retrieving Results forShitanjing
# ------------
# Retrieving Results forPacific Grove
# ------------
# Retrieving Results forCape Coast
# ------------
# Retrieving Results forMuros
# ------------
# Retrieving Results forDisna
# ------------
# Retrieving Results forYuncheng
# ------------
# Retrieving Results forTuraif
# ------------
# Retrieving Results forKincardine
# ------------
# Retrieving Results forNambucca Heads
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forAhome
# ------------
# Retrieving Results forTilichiki
# ------------
# Retrieving Results forTuatapere
# ------------
# Retrieving Results forEnumclaw
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forMaţāy
# ------------
# Retrieving Results forShubarshi
# ------------
# Retrieving Results forWāshīm
# ------------
# Retrieving Results forGaoual
# ------------
# Retrieving Results forRibeira Brava
# ------------
# Retrieving Results forLyuban'
# ------------
# Retrieving Results forChimala
# ------------
# Retrieving Results forShimanovsk
# ------------
# Retrieving Results forTakoradze
# ------------
# Retrieving Results forUulu
# ------------
# Retrieving Results forManono
# ------------
# Retrieving Results forProgreso
# ------------
# Retrieving Results forDomoni
# ------------
# Retrieving Results forNizhniy Ingash
# ------------
# Retrieving Results forKostomuksha
# ------------
# Retrieving Results forShihezi
# ------------
# Retrieving Results forPochutla
# ------------
# Retrieving Results forConakry
# ------------
# Retrieving Results forKlos
# ------------
# Retrieving Results forPort Hardy
# ------------
# Retrieving Results forNānākuli
# ------------
# Retrieving Results forPresidencia Roque Sáenz Peña
# ------------
# Retrieving Results forOussouye
# ------------
# Retrieving Results forKandrian
# ------------
# Retrieving Results forWad Rāwah
# ------------
# Retrieving Results forSt Albans
# ------------
# Retrieving Results forAksarka
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forAlbion
# ------------
# Retrieving Results forJambi City
# ------------
# Retrieving Results forNotsé
# ------------
# Retrieving Results forElizabeth City
# ------------
# Retrieving Results forSarangani
# ------------
# Retrieving Results forArrondissement d'Ajaccio
# ------------
# Retrieving Results forTessalit
# ------------
# Retrieving Results forTire
# ------------
# Retrieving Results forJuneau
# ------------
# Retrieving Results forMezhdurechenskiy
# ------------
# Retrieving Results forHalf Moon Bay
# ------------
# Retrieving Results forLe Port
# ------------
# Retrieving Results forCoquimbo
# ------------
# Retrieving Results forBiankouma
# ------------
# Retrieving Results forBiharamulo
# ------------
# Retrieving Results forSakakah
# ------------
# Retrieving Results forEureka
# ------------
# Retrieving Results forSępólno Krajeńskie
# ------------
# Retrieving Results forTalakan
# ------------
# Retrieving Results forDarnah
# ------------
# Retrieving Results forTaveta
# ------------
# Retrieving Results forKemijärvi
# ------------
# Retrieving Results forBosaso
# ------------
# Retrieving Results forAntsohihy
# ------------
# Retrieving Results forToccoa
# ------------
# Retrieving Results forNara
# ------------
# Retrieving Results forVardø
# ------------
# Retrieving Results forPascagoula
# ------------
# Retrieving Results forMâncio Lima
# ------------
# Retrieving Results forProvideniya
# ------------
# Retrieving Results forNalhāti
# ------------
# Retrieving Results forKetchikan
# ------------
# Retrieving Results forYeppoon
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forRío Gallegos
# ------------
# Retrieving Results forNouakchott
# ------------
# Retrieving Results forKalevala
# ------------
# Retrieving Results forAlta Floresta
# ------------
# Retrieving Results forBanfora
# ------------
# Retrieving Results forSampit
# ------------
# Retrieving Results forTongchuanshi
# ------------
# Retrieving Results forReconquista
# ------------
# Retrieving Results forKosonsoy
# ------------
# Retrieving Results forCarutapera
# ------------
# Retrieving Results forManjacaze
# ------------
# Retrieving Results forEvensk
# ------------
# Retrieving Results forSaint-François
# ------------
# Retrieving Results forJalu
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forKillybegs
# ------------
# Retrieving Results forBara
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Retrieving Results forWilliams Lake
# ------------
# Retrieving Results forChuchkovo
# ------------
# Retrieving Results forManyoni
# ------------
# Retrieving Results forRørvik
# ------------
# Retrieving Results forTual
# ------------
# Retrieving Results forLaas
# ------------
# Retrieving Results forAtambua
# ------------
# Retrieving Results forKieta
# ------------
# Retrieving Results forPetropavlovka
# ------------
# Retrieving Results forRomitan
# ------------
# Retrieving Results forMount Gambier
# ------------
# Retrieving Results forIsla Aguada
# ------------
# Retrieving Results forAklavik
# ------------
# Retrieving Results forTura
# ------------
# Retrieving Results forBalyqshy
# ------------
# Retrieving Results forVila
# ------------
# Retrieving Results forJacmel
# ------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create a Dictionary
Raw_data = {"City":name,"Latitude": lat,"Longitude": lng, "Temperature": temp, "Humidity":humid, "Cloudiness": clouds,
           "Wind Speed": wind, "Country": country}
#Convert Dictionary to DataFrame
Weather_Results_df = pd.DataFrame(Raw_data)
#Write DataFrame to CSV file "cities.csv"
Weather_Results_df.to_csv(output_data_file)
Weather_Results_df.head()
# Out:
#                City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0         Cape Town    -33.93      18.42        60.58        77          75
# 1      Puerto Ayora     -0.74     -90.35        69.01        90          68
# 2       East London    -33.02      27.91        69.89        87           0
# 3              Naze     28.37     129.48        75.20        78          75
# 4  Praia da Vitória     38.73     -27.07        64.24        82          40
#
#    Wind Speed Country
# 0        2.24      ZA
# 1        7.00      EC
# 2        6.58      ZA
# 3       20.80      JP
# 4        7.78      PT

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Temperature (F) vs. Latitude

x_value= Weather_Results_df["Latitude"]
y_value= Weather_Results_df["Temperature"]
plt.title("City Latitude vs. Temperature (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "springgreen", edgecolors="mediumblue", alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel("Temperature (F)")
plt.grid(True)
plt.tight_layout()
#plt.show()
plt.savefig("./output_data/Citiesfig1.png")

# %% [markdown]
# This plot shows correlation by showing that in between -20 and 20 Latitude is the cities with the higher temperatures

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Humidity (%) vs. Latitude
x_value= Weather_Results_df["Latitude"]
y_value= Weather_Results_df["Humidity"]
plt.title("City Latitude vs. Humidity (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "lime", edgecolors="indigo")
plt.xlabel('Latitude')
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.tight_layout()
#plt.show()
plt.savefig("./output_data/Citiesfig2.png")

# %% [markdown]
# This plot is analyzing the humidity of cities in between

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Cloudiness (%) vs. Latitude
x_value= Weather_Results_df["Latitude"]
y_value= Weather_Results_df["Cloudiness"]
plt.title("City Latitude vs. Cloudiness (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "deepskyblue", edgecolors="orchid")
plt.xlabel('Latitude')
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.tight_layout()
#plt.show()
plt.savefig("./output_data/Citiesfig3.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Wind Speed (mph) vs. Latitude
x_value= Weather_Results_df["Latitude"]
y_value= Weather_Results_df["Wind Speed"]
plt.title("City Latitude vs. Wind Speed (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "mediumturquoise", edgecolors="blue")
plt.xlabel('Latitude')
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.tight_layout()
#plt.show()
plt.savefig("./output_data/Citiesfig4.png")

# %% [markdown]
# ## Linear Regression

# %%
Northern_hemisphere_df = Weather_Results_df.loc[Weather_Results_df["Latitude"]>=0]
Southern_hemisphere_df = Weather_Results_df.loc[Weather_Results_df["Latitude"]<0]
#print(type(Southern_hemisphere_df))

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_value= Northern_hemisphere_df["Latitude"]
y_value= Northern_hemisphere_df["Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=20,color="red")

plt.title("Northern Hemisphere - City Latitude vs. Temperature (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "springgreen", edgecolors="mediumblue", alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel("Temperature (F)")
plt.tight_layout()
print(f"R squared: {rvalue**2}")
plt.show()
# Out:
# R squared: 0.7885878558172447

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_value= Southern_hemisphere_df["Latitude"]
y_value= Southern_hemisphere_df["Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(-40,50),fontsize=20,color="red")

plt.title("Southern Hemisphere - City Latitude vs. Temperature (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "springgreen", edgecolors="mediumblue", alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel("Temperature (F)")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value= Northern_hemisphere_df["Latitude"]
y_value= Northern_hemisphere_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(30,20),fontsize=20,color="red")

plt.title("Northern Hemisphere - City Latitude vs. Humidity (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "lime", edgecolors="indigo")
plt.xlabel('Latitude')
plt.ylabel("Humidity (%)")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value= Southern_hemisphere_df["Latitude"]
y_value= Southern_hemisphere_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=20,color="red")

plt.title("Southern Hemisphere - City Latitude vs. Humidity (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "lime", edgecolors="indigo")
plt.xlabel('Latitude')
plt.ylabel("Humidity (%)")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value= Northern_hemisphere_df["Latitude"]
y_value= Northern_hemisphere_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=20,color="red")

plt.title("Northern Hemisphere - City Latitude vs. Cloudiness (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "deepskyblue", edgecolors="orchid")
plt.xlabel('Latitude')
plt.ylabel("Cloudiness (%)")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value= Southern_hemisphere_df["Latitude"]
y_value= Southern_hemisphere_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=20,color="red")

plt.title("Southern Hemisphere - City Latitude vs. Cloudiness (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "deepskyblue", edgecolors="orchid")
plt.xlabel('Latitude')
plt.ylabel("Cloudiness (%)")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value= Northern_hemisphere_df["Latitude"]
y_value= Northern_hemisphere_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(6,22),fontsize=20,color="red")

plt.title("Northern Hemisphere - City Latitude vs. Wind Speed (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "mediumturquoise", edgecolors="blue")
plt.xlabel('Latitude')
plt.ylabel("Wind Speed (mph)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value= Southern_hemisphere_df["Latitude"]
y_value= Southern_hemisphere_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_value,regress_values,"r-")
plt.annotate(line_eq,(-50,5),fontsize=20,color="red")

plt.title("Southern Hemisphere - City Latitude vs. Wind Speed (11/13/2020)")
plt.scatter(x_value,y_value, marker= "o", facecolors= "mediumturquoise", edgecolors="blue")
plt.xlabel('Latitude')
plt.ylabel("Wind Speed (mph)")
plt.show()
